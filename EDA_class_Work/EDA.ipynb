# %%
import pandas as pd
# Out:
# hello

# %%
import pandas as pd
df=pd.read_csv('adult_eda.csv')
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df[df['sex']=="Female"]
# Out:
#        age     workclass  fnlwgt     education  education-num  \
# 4       28       Private  338409     Bachelors           13.0
# 5       37       Private  284582       Masters           14.0
# 6       49       Private  160187           9th            5.0
# 8       31       Private   45781       Masters           14.0
# 12      23       Private  122272     Bachelors           13.0
# ...    ...           ...     ...           ...            ...
# 32546   37       Private  198216    Assoc-acdm           12.0
# 32549   43     State-gov  255835  Some-college           10.0
# 32556   27       Private  257302    Assoc-acdm           12.0
# 32558   58       Private  151910       HS-grad            9.0
# 32560   52  Self-emp-inc  287927       HS-grad            9.0
#
#               marital-status       occupation    relationship   race     sex  \
# 4         Married-civ-spouse   Prof-specialty            Wife  Black  Female
# ...

# %%
df[df["salary"]>'20K']
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# find dublicate rows and drop duplicate rows

# %%
df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# Name: count, dtype: int64

# %% [markdown]
# drop duplicate

# %%
df=df.drop_duplicates()
df.duplicated().value_counts()
# Out:
# False    32537
# Name: count, dtype: int64

# %% [markdown]
# Find the shape of the data.

# %%
df.shape
# Out:
# (32537, 15)

# %% [markdown]
# : Find the basic stats of the data.

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32537.000000  3.253700e+04   31735.000000  32537.000000  32537.000000
# mean      38.585549  1.897808e+05      10.084008   1078.443741     87.368227
# std       13.637984  1.055565e+05       2.575060   7387.957424    403.101833
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369930e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %% [markdown]
# Step-6: Rename the columns(optional)

# %%
df.columns=df.columns.str.replace("_","_")
df.columns

df.rename(columns={'age':'agee'},inplace=True)
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns=df.columns.str.replace("_","_")
#       2 df.columns
#       4 df.rename(columns={'age':'agee'},inplace=True)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv('adult_eda.csv')
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df=pd.read_csv('Titanic-Dataset.csv')
df.head()
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.duplicated().value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool>

# %% [markdown]
# data collection
#
# Numrical( Quantitive) Data Analysis

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 6.6 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/8.1 MB 6.6 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.1 MB 2.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.1 MB 2.3 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/8.1 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 2.4 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 2.4 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 2.4 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 2.4 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 1.5 MB/s eta 0:00:04
#    --------------- ------------------------ 3.1/8.1 MB 1.5 MB/s eta 0:00:04
# ...

# %%
pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    - -------------------------------------- 1.3/41.0 MB 6.6 MB/s eta 0:00:07
#    -- ------------------------------------- 2.1/41.0 MB 6.2 MB/s eta 0:00:07
#    -- ------------------------------------- 2.6/41.0 MB 3.9 MB/s eta 0:00:10
#    -- ------------------------------------- 2.9/41.0 MB 3.3 MB/s eta 0:00:12
#    --- ------------------------------------ 3.1/41.0 MB 3.2 MB/s eta 0:00:12
#    --- ------------------------------------ 3.4/41.0 MB 2.8 MB/s eta 0:00:14
#    --- ------------------------------------ 3.7/41.0 MB 2.6 MB/s eta 0:00:15
#    --- ------------------------------------ 3.7/41.0 MB 2.6 MB/s eta 0:00:15
#    --- ------------------------------------ 3.7/41.0 MB 2.6 MB/s eta 0:00:15
#    --- ------------------------------------ 3.9/41.0 MB 1.7 MB/s eta 0:00:22
#    --- ------------------------------------ 3.9/41.0 MB 1.7 MB/s eta 0:00:22
# ...

# %%
import pandas as np 

import matplotlib.pyplot as plt
# import seaborn as sp

import numpy as np

data ={'month',['January','Fabruary','March','April','May','June','July','August','Septemper','October','November','December'],'Sales (Units)': [110,120,170,140,150,155,180,190,195,210,220,230]
       }

# %%
plt.subplot(1,2,1)
ana.barplot(x='month',y='seles(unit)',data=df.palette='Blues_d'")"
plt.xtitle('month salaes bar char,',fontsize=16)
plt.ytitle('sales(unit)',fontsize=12)
plt.xticks(rotation=45)

# %% [markdown]
# login pie char
#
# plt.subplot(1,2,3)
#
# plt.pie(df['seles(unit)'], labes=df['month],autopct='%1.1f%%', startangle=140)
# colors=sns.color_palette('Blues_d',;len(df))
# plt.title('sales distribution by month', fontsize=16)

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
plt.plot(df['month'],df['sales (units)'],
          marker='0',color='b',linesstyle='-',markersize=8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot(df['month'],df['sales (units)'],
#       2           marker='0',color='b',linesstyle='-',markersize=8)
#
# NameError: name 'df' is not defined

# %%
#convert the data into a data Frame 
df=pd.DataFrame(data)

df['moving avarage (3 MONOTH)']=df['sales(units)'].rolling(window=3).mean
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 #convert the data into a data Frame
# ----> 2 df=pd.read_csv('data.csv')
#       3 df=pd.DataFrame(data)
#       5 df['moving avarage (3 MONOTH)']=df['sales(units)'].rolling(window=3).mean
#
# ...
